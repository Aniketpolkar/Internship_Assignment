# %% [markdown]
# ### Data ingestion

# %%
###Document Structure
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the main text content I am using to create RAG ",
    metadata = {
        "source":"example.txt",
        "pages":1,
        "author":"Aniket Polkar",
        "date_created":"2026-01-01"
    }
)

# %%
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Aniket Polkar', 'date_created': '2026-01-01'}, page_content='This is the main text content I am using to create RAG ')

# %%
###Simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader 
# from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
###Directory Loader 
from langchain_community.document_loaders import DirectoryLoader

### Load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", #pattern to match files 
    loader_cls=TextLoader, #loader class to use
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

document = dir_loader.load()
document
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
###Directory Loader 
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader

### Load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", #pattern to match files 
    loader_cls=PyMuPDFLoader, #loader class to use
    show_progress=False
)

pdf_document = dir_loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.6', 'creationdate': '2025-12-01T07:54:51+00:00', 'source': '..\\data\\pdf\\1dec ticket.pdf', 'file_path': '..\\data\\pdf\\1dec ticket.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': 'redBus', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251201075451Z', 'page': 0}, page_content='Mahalaxmi Bus (Lokre Bandhu)\nNon A/C Seater / Sleeper (2+1)\nTravels\nRs. 420.0\n(inclusive of GST) \nTicket Price\nPune\nNigadi\nLIC Corner ,Nigadi\nLandmark: Lic Corner\n8828794402 8828794404 8828794405\n8828794402 8828794404 8828794405\nBoarding Point\nNesari\nNesari,Kolhapur\nDROPPING DATE & TIME:\n02/12/2025, 07:45 AM\nDropping Point\nPassenger Details\nSeat no\nAniket Polkar\n21Yrs, MALE\n11W\nredBus Ticket Information\nPune-Nesari on Monday, December 1, 2025\nTicket Number: TUCU58609997   |   PNR No: 469735\nHey Aniket Polkar,\nHurray!! You have saved Rs 20.00 on this booking\nCurrent redBus wallet balance\n₹ 75.0\nTicket Details\nJourney Date and Time\n01/12/2025, 09:30 PM\nFare breakup:\nBase fare\n₹Rs. 420.0\nConvenience fee\n₹\nGST\n₹(Rs. 20.0 inclusive of GST and service charge, if any)\nTotal\n₹'),
#  Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.6', 'creationdate': '2025-12-01T07:54:51+00:00', 'source': '..\\data\\pdf\\1dec ticket.pdf', 'file_path': '..\\data\\pdf\\1dec ticket.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': 'redBus', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251201075451Z', 'page': 1}, page_content='Congrats on booking a Primo bus! \nEnjoy top rated features\nPunctual\nClean\nComfortable\nDate change\nThe journey date for this ticket can be changed, you can advance or postpone the ticket to a different date as per your convenience.\nDate change time and charges for this operator is shown below.\nTime\nCharges\nDate change allowed till 01 Dec 2025 01:00 PM \n(8 hours before departure)\n  FREE\nNote: Rescheduling a ticket can be availed only once per booking, if applicable. Once the travel date change option is availed, the\nticket cannot be further cancelled.\nHow to Change the journey date of your ticket in redbus app\nGo to my bookings, choose the journey & change date\nCancellation policy\nYour current cancellation charges according to the cancellation policy is highlighted below\nCancellation time\nCancellation charges\n  Before 24th Nov 10:00 PM\n  Rs. 40.0(10%)\n  After 24th Nov 10:00 PM & Before 28th Nov 10:00 PM\n  Rs. 120.0(30%)\n  After 28th Nov 10:00 PM & Before 30th Nov 10:00 PM\n  Rs. 200.0(50%)\n  After 30th Nov 10:00 PM & Before 1st Dec 07:00 PM\n  Rs. 400.0(100%)\n  After 1st Dec 07:00 PM & Before 1st Dec 10:00 PM\n  Rs. 400.0(100%)\nCancellation charges are computed on per seat basis.\nFor Group bookings, cancellation of individual seats is not allowed.\nNote: Cancellation charges mentioned above are excluding GST.\nHow to cancel your ticket on redbus app\nGo to my bookings and choose the journey and cancel the ticket'),
#  Document(metadata={'producer': 'Qt 4.8.7', 'creator': 'wkhtmltopdf 0.12.6', 'creationdate': '2025-12-01T07:54:51+00:00', 'source': '..\\data\\pdf\\1dec ticket.pdf', 'file_path': '..\\data\\pdf\\1dec ticket.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': 'redBus', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20251201075451Z', 'page': 2}, page_content="Need help? redBuddy is here for you!\n24x7 support\nQuick Resolution\nMultilingual\nCHAT WITH REDBUDDY\nTravel Guidelines\nPlease note it is mandatory to follow the travel guidelines of your source and destination state of travel.\nView Guidelines: https://bit.ly/redbus-guidelines\nTerms and conditions\n1. redBus* is an online ticketing platform. It does not operate bus services of its own. In order to provide a comprehensive choice of bus operators, departure\ntimes and prices to customers, it has tied up with many bus operators.\nredBus responsibilities include:\n(1) Issuing a valid ticket (a ticket that will be accepted by the bus operator) for its network of bus operators\n(2) Providing refund and support in the event of cancellation\n(3) Providing customer support and information in case of any delays / inconvenience\nredBus responsibilities do not include:\n(1) The bus operator's bus not departing / reaching on time.\n(2) The bus operator's employees being rude.\n(3) The bus operator's bus seats etc not being up to the customer's expectation.\n(4) The bus operator canceling the trip due to unavoidable reasons.\n(5) The baggage of the customer getting lost / stolen / damaged.\n(6) The bus operator changing a customer's seat at the last minute to accommodate a lady / child.\n(7) The customer waiting at the wrong boarding point (please call the bus operator to find out the exact boarding point if you are not a regular traveler on\nthat particular bus).\n(8) The bus operator changing the boarding point and/or using a pick-up vehicle at the boarding point to take customers to the bus departure point.\n2. The departure time mentioned on the ticket are only tentative timings. However the bus will not leave the source before the time that is mentioned on the\nticket.\n3. Passengers are required to furnish the following at the time of boarding the bus: \n(1) A digital copy of the e-ticket or m-ticket. \n(2) A valid identity proof \nFailing to do so, they may not be allowed to board the bus.\n4. Change of bus: In case the bus operator changes the type of bus due to some reason, redBus will refund the differential amount to the customer upon\nbeing intimated by the customers in 24 hours of the journey.\n5. Amenities for this bus as shown on redBus have been configured and provided by the bus provider (bus operator). These amenities will be provided\nunless there are some exceptions on certain days. Please note that redBus provides this information in good faith to help passengers to make an\ninformed decision. The liability of the amenity not being made available lies with the operator and not with redBus.\n6. In case a booking confirmation e-mail and sms gets delayed or fails because of technical reasons or as a result of incorrect e-mail ID / phone number\nprovided by the user etc, a ticket will be considered 'booked' as long as the ticket shows up on the confirmation page of www.redBus.in\n7. Grievances and claims related to the bus journey should to be reported to redBus support team within 7 days of your Travel date.\n8. Cancellation of this ticket is NOT allowed after bus departure time."),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-10T22:34:29+05:30', 'source': '..\\data\\pdf\\Akash Polkar Resume.pdf', 'file_path': '..\\data\\pdf\\Akash Polkar Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': 'Microsoft Word - Nikhil Patil', 'author': 'admin', 'subject': '', 'keywords': '', 'moddate': '2025-12-10T22:34:29+05:30', 'trapped': '', 'modDate': "D:20251210223429+05'30'", 'creationDate': "D:20251210223429+05'30'", 'page': 0}, page_content='EXPERINECE \nAkash Krishna Polkar \nCAREER OBJECTIVE \nACADEMIC PROFILE \n \nCURRICULUM VITAE \n \n \n \nA/P-Kumari, Tal-Gadhinglaj, \nDist: Kolhapur \nPin:416502. \n \nE-mail: akashpolkar99@gmail.com \nMobile: 9923362568 \n \n \nTo find a challenging position in Research division in rapidly growing Industry where \nI can best utilize my knowledge and technical skills. \n \n \nSr. No. \nExam Passed \nUniversity/Board \nYear of Passing \n% Marks \n1 \nS.S.C. \nDivisional Board \nKolhapur \n2015-16 \n72.00 % \n2 \nH.S.C. \nDivisional Board \nKolhapur \n2017-18 \n52.00 % \n1 \nB.Sc. -I \nShivaji University, \nKolhapur \n2018-19 \n62.00 % \n2 \nB.Sc. -II \nShivaji University, \nKolhapur \n2020-21 \n75.00 % \n3 \nB.Sc. -III \nShivaji University, \nKolhapur \n2021-22 \n72.00 % \n \n \n➢ ENCUBE ETHICALS PVT LTD, Goa \nOne-year experience in Quality control \n \n➢ PFIZER PVT LTD, Goa \nDepartment of warehouse currently working (One Year experience) \n \n• \nHandled raw material arrangements, dispensing, and online BMR entry. \n• \nMaintained calibration records and operated weighing balances. \n• \nPerformed cleaning procedures for RLAF and vacuum equipment. \n• \nManaged online documentation with timely entries across systems. \n• \nEnsured compliance with SOPs and maintained GMP practices in the store \n• \nUpdated new material data and rack locations in E-Track system'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-10T22:34:29+05:30', 'source': '..\\data\\pdf\\Akash Polkar Resume.pdf', 'file_path': '..\\data\\pdf\\Akash Polkar Resume.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': 'Microsoft Word - Nikhil Patil', 'author': 'admin', 'subject': '', 'keywords': '', 'moddate': '2025-12-10T22:34:29+05:30', 'trapped': '', 'modDate': "D:20251210223429+05'30'", 'creationDate': "D:20251210223429+05'30'", 'page': 1}, page_content='COMPUTER SKILS   \n⮚ \nHOBBIES \nSTRENGTH \nDECLARATION \n \n• \nBasic knowledge of Computer & MS-CIT \n• \nMicrosoft Word \n• \nMicrosoft PowerPoint \n \n \n \n⮚ Date of Birth \n: \n25th June 1999 \n⮚ Gender \n: \nMale \n⮚ Nationality \n: \nIndian \n⮚ Marital Status \n: \nSingle \n⮚ Languages \n: \nEnglish, Hindi & Marathi. \n \n \n⮚ Trekking. \n⮚ Listening music \n⮚ Cricket \n \n \n⮚ Positive Attitude and Enthusiastic in team work. \n⮚ Ability to handle crunch situation and adapt to any environment. \n \n \nI do herby declare that the particulars of information and facts stated herein \nabove are true, correct and complete to the best of my knowledge and belief. \n \n \n \nPLACE : Gadhinglaj \nYours Faithfully , \n \nDATE : \nAkash Krishna Polkar \nPERSONAL INFORMATION'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-11T20:26:26+05:30', 'source': '..\\data\\pdf\\CC_Questions_25-25[1].pdf', 'file_path': '..\\data\\pdf\\CC_Questions_25-25[1].pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'dyp', 'subject': '', 'keywords': '', 'moddate': '2025-12-11T20:26:26+05:30', 'trapped': '', 'modDate': "D:20251211202626+05'30'", 'creationDate': "D:20251211202626+05'30'", 'page': 0}, page_content='Sample questions of Cloud Computing \n \nNote: Questions 1–24 are from Week 1 to Week 6 notes, which have already been provided to you. \nThey will be shared again if needed. From Question 25 onward, please prepare the answers on your \nown. \n \n1. What is Public Cloud? State Advantages and Disadvantages. \n2. Differentiate between the Centralized and Distributed Computing. \n3. What is Cloud Computing? State Components of Cloud Computing. \n4. Explain Characteristics of Cloud Computing. \n5. List cloud service models. Explain any two in detail. \n6. Draw virtualization architecture with explanation. \n7. Explain the concept of virtualization in cloud computing. Discuss its different types \n8. Explain Security issues in cloud computing. \n9. Discuss the role of SLAs in cloud computing. Explain the SLA lifecycle. \n10. Define Map-Reduce in cloud computing and describe its working mechanism. \n11. What is Capital Cost? Explain pricing strategies. \n12. Define open stack. List and explain components of open stack \n13. What is Cloud Management? Why cloud management? \n14. Differentiate between Public Cloud, Private Cloud and Hybrid Cloud. \n15. Explain Fog computing in detail. \n16. Explain advantages and disadvantages of cloud computing. \n17. List cloud service models. Compare cloud service models. \n18. Describe the Deployment model with architecture. \n19. Explain cloud security with respect to its components. \n20. Explain Cloud Properties with respect to economic point of view. \n21. What is Cloud Security Architecture? Why Cloud Security Architecture Is Important \n22. Explain Components of Cloud Security Architecture \n23. Why Cloud security is important? Explain in detail. \n24. How to Build Cloud Security Architecture. \n25. List types of Grids? Explain any one in detail. \n26. What is Cluster Computing? Explain components of clusters \n27. Describe the Deployment model with architecture. \n28. List types of grid. Explain any one in detail. \n29. Explain advantages and disadvantages of cloud computing. \n30. Explain cloud security with respect to its components. \n31. What is mobile computing? Explain benefits with respect to mobile computing. \n32. What is mobile computing? Explain challenges & application with respect to mobile \ncomputing. \n33. Explain Fog computing in detail. \n34. Differentiate between cloud computing & fog computing. \n35. Describe the working of Microsoft Azure with diagram. \n36. What is Sensor Cloud Computing? Explain Overview of Sensor-Cloud Framework. \n37. What is Virtualizations? Give any Three application of virtualization \n38. Differentiate between Public cloud and Private cloud.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-12-11T20:26:26+05:30', 'source': '..\\data\\pdf\\CC_Questions_25-25[1].pdf', 'file_path': '..\\data\\pdf\\CC_Questions_25-25[1].pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'dyp', 'subject': '', 'keywords': '', 'moddate': '2025-12-11T20:26:26+05:30', 'trapped': '', 'modDate': "D:20251211202626+05'30'", 'creationDate': "D:20251211202626+05'30'", 'page': 1}, page_content='39. State features of Cloud Service Models \n40. Draw and explain Cloud Computing Architecture. \n41. Draw and explain Life Cycle of Service Level Agreement (SLA). \n42. Draw and explain Cloud Computing Architecture. \n43. Describe IoT Cloud Systems in detail. \n44. List any four innovative applications of Cloud with Internet of Things.'),
#  Document(metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-11-03T12:47:18+05:30', 'source': '..\\data\\pdf\\IMP Question Bank -ADAS.pdf', 'file_path': '..\\data\\pdf\\IMP Question Bank -ADAS.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Manish Narkhede', 'subject': '', 'keywords': '', 'moddate': '2025-11-03T12:47:18+05:30', 'trapped': '', 'modDate': "D:20251103124718+05'30'", 'creationDate': "D:20251103124718+05'30'", 'page': 0}, page_content='Question Bank: ADAS \n1. Define Advanced Driver Assistance System (ADAS) and state its main objectives. \n2. Differentiate between passive and active safety systems in vehicles. \n3. Describe the role of automation levels in driver assistance and vehicle autonomy. \n4. Explain how ADAS contributes to improving overall vehicle safety and driver \ncomfort. \n5. Discuss the limitations of early-generation driver assistance technologies. \n6. Explain the importance of electronic control units (ECUs) in implementing ADAS \nfunctions. \n7. Describe the integration of ADAS modules with a vehicle’s CAN communication bus. \n8. Analyze how human factors influence the design of ADAS interfaces and alerts. \n9. List the types of sensors commonly used in ADAS and describe their functions. \n10. Compare LiDAR, RADAR, and camera sensors based on resolution and range. \n11. Explain how sensor fusion improves environmental perception accuracy. \n12. Discuss the challenges faced by ADAS sensors under adverse weather conditions. \n13. Illustrate how ultrasonic sensors are used for low-speed detection and parking. \n14. Explain the concept of distributed sensor architecture in ADAS networks. \n15. Describe how vehicle blind spot detection is implemented using radar sensors. \n16. Discuss how calibration errors affect ADAS sensor performance and reliability. \n17. Define computer vision and its significance in driver assistance systems. \n18. Explain the working of an AI-based object recognition system using camera inputs. \n19. Illustrate the process of lane detection using deep learning models. \n20. Discuss the role of convolutional neural networks (CNNs) in vision-based driving. \n21. Analyze the limitations of current AI algorithms in unseen traffic conditions. \n22. Explain how datasets and data annotation contribute to AI model training for ADAS. \n23. Describe the workflow of an AI-based pedestrian detection and alert system. \n24. Discuss the use of reinforcement learning in improving autonomous decision-making. \n25. Explain how semantic segmentation assists in scene understanding for autonomous \nvehicles. \n26. Compare rule-based algorithms with AI-based perception systems in ADAS. \n27. Explain the concept and operation of Adaptive Cruise Control (ACC). \n28. Describe how Forward Collision Warning (FCW) helps prevent accidents. \n29. Explain the working principle of Automatic Emergency Braking (AEB).'),
#  Document(metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-11-03T12:47:18+05:30', 'source': '..\\data\\pdf\\IMP Question Bank -ADAS.pdf', 'file_path': '..\\data\\pdf\\IMP Question Bank -ADAS.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Manish Narkhede', 'subject': '', 'keywords': '', 'moddate': '2025-11-03T12:47:18+05:30', 'trapped': '', 'modDate': "D:20251103124718+05'30'", 'creationDate': "D:20251103124718+05'30'", 'page': 1}, page_content='30. Discuss how Lane Departure Warning (LDW) systems detect and respond to drifts. \n31. Describe the functioning of Evasive Steering Assist in critical driving scenarios. \n32. Explain how the Rear Cross Traffic Alert (RCTA) system detects approaching \nvehicles. \n33. Describe how Driver Drowsiness Detection systems operate using camera sensors. \n34. Compare manual parking, semi-automatic, and fully automated parking systems. \n35. Explain how Vehicle Stability Control (VSC) enhances safety during cornering. \n36. Discuss how intelligent headlights automatically adjust brightness and beam pattern. \n37. Define ADAS calibration and explain why it is necessary. \n38. Compare online calibration and end-of-line (EOL) calibration procedures. \n39. Discuss the role of calibration environments in ensuring accurate system operation. \n40. Explain functional versus service calibration in sensor maintenance. \n41. Describe the process of calibrating a rear camera system for parking assistance. \n42. Explain how software validation ensures ADAS reliability after calibration. \n43. Discuss the consequences of poor calibration on vehicle safety systems. \n44. Explain the use of simulation platforms in testing and validating ADAS features. \n45. Illustrate a structured approach to ADAS testing under different traffic scenarios. \n46. Describe how sensor data is logged and analyzed during validation trials. \n47. Discuss the role of V2X (Vehicle-to-Everything) communication in extending ADAS \ncapabilities. \n48. Explain how over-the-air (OTA) updates enhance the performance of ADAS features. \n49. Predict the challenges of integrating ADAS into fully autonomous vehicles. \n50. Describe ethical considerations in decision-making for AI-based driver assistance \nsystems.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 0}, page_content='1 \n \nPIMPRI CHINCHWAD COLLEGE OF ENGINEERING, PUNE \n(An Autonomous Institute affiliated to Savitribai Phule Pune University) \nDEPARTMENT OF INFORMATION TECHNOLOGY \n \n \n \nNPTEL COURSE REPORT \n \non \n“Cloud Computing” \n \n \nSubmitted by: \nName of Student: Aniket Vilas Polkar \nRoll No.: 122B1F104 \nClass & Division: BTech-B \n \n \nAcademic Year: 2025–26'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 1}, page_content='2 \n \n \nTABLE OF CONTENTS \nSr. No. \nContent \nPage No. \n1 \nIntroduction \n3 \n2 \nWeek 1: Introduction to Cloud Computing \n3 \n3 \nWeek 2: Cloud Computing Architecture \n4 \n4 \nWeek 3: Service Management in Cloud \nComputing \n5 \n5 \nWeek 4: Data Management in Cloud Computing \n5 \n6 \nWeek 5: Resource Management in Cloud \n6 \n7 \nWeek 6: Cloud Security \n7 \n8 \nWeek 7: Open Source and Commercial Clouds, \nCloud Simulator \n8 \n9 \nWeek 8: Research trend in Cloud Computing, \nFog Computing \n9 \n10 \nWeek 9: VM Resource Allocation, Management \nand Monitoring \n9 \n11 \nWeek 10: Cloud-Fog-Edge enabled Analytics \n10 \n12 \nWeek 11: Serverless Computing and FaaS \nModel \n11 \n13 \nWeek 12: Case Studies and Recent \nAdvancements \n11 \n14 \nConclusion \n12'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 2}, page_content='3 \n \n1. INTRODUCTION \n \nCloud Computing has emerged as one of the most transformative technologies in the \nevolving digital landscape. It provides flexible, scalable, and cost-efficient \ncomputational resources over the internet. The NPTEL Cloud Computing course \noffers a complete understanding of cloud fundamentals, architectures, visualization \ntechnologies, service models, security mechanisms, and advanced topics such as Fog \nComputing, Serverless Computing, Cloud–Edge collaboration, and emerging research \ntrends. \n \nThis report summarizes all 12 weeks of the course in detail, explaining key theories, \nmechanisms, architectures, examples, case studies, and real-world applications. \n2. WEEK 1 – Cloud Computing Overview & Architecture \n2.1 Definition \nCloud Computing is defined as a model that enables on-demand network access to a \nshared pool of configurable computing resources (like networks, servers, storage, \napplications, and services) that can be rapidly provisioned with minimal \nmanagement effort. \n2.2 Essential Characteristics \n1. On-Demand Self-Service – Users can access resources without human \nintervention from the provider. \n2. Broad Network Access – Services accessible from laptops, mobile, browsers. \n3. Resource Pooling – Multi-tenancy and shared infrastructure. \n4. Rapid Elasticity – Scaling up or down automatically. \n5. Measured Service – Usage-based billing and monitoring. \n2.3 Cloud Deployment Models \n• \nPublic Cloud – Hosted by third-party vendors. (AWS, GCP, Azure) \n• \nPrivate Cloud – Exclusively used by one organization. \n• \nHybrid Cloud – Combination of public and private. \n• \nCommunity Cloud – Shared by groups with common interests. \n2.4 Cloud Architecture'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 3}, page_content='4 \n \nFront End \nDevices, client applications, browsers, APIs. \nBack End \nServers, storage systems, databases, hypervisors, cloud management software. \n3. WEEK 2 – Virtualization, XML, SOA, and Web Services \n3.1 Virtualization \nVirtualization enables multiple virtual machines (VMs) to run on a single physical \nsystem. \nTypes of Virtualization \n1. Full Virtualization – VM is unaware it is virtualized; complete abstraction. \n2. Para-Virtualization – VM is aware of virtualization; improves performance. \n3. Hardware-Assisted Virtualization – Uses technologies like Intel VT-x or AMD-\nV. \n3.2 Benefits of Virtualization \n• \nEfficient resource usage \n• \nEasy provisioning \n• \nFault isolation \n• \nImproved scalability \n3.3 XML & Web Services \n• \nXML is used for data exchange in service-oriented models. \n• \nWeb services use SOAP, REST, WSDL, UDDI, etc. \n3.4 SOA (Service-Oriented Architecture) \nKey features: \n• \nLoose coupling \n• \nInteroperability \n• \nReusability \n• \nStandardized communication'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 4}, page_content='5 \n \n \n4. WEEK 3- SLA, Cloud Economics & MapReduce  \n4.1 Service Level Agreement (SLA) \nSLA defines: \n• \nUptime \n• \nPerformance \n• \nResponse time \n• \nSupport availability \nSLA also includes penalties for non-compliance. \n4.2 Cloud Economics \n• \nPay-as-you-go model \n• \nOperational expenditure instead of capital expenditure \n• \nResource optimization techniques \n4.3 Data Management \n• \nDistributed storage \n• \nReplication \n• \nConsistency models (strong, eventual, causal) \n4.4 MapReduce \nA programming model for large-scale data processing. \n• \nMap phase – Converts input data into key-value pairs. \n• \nReduce phase – Aggregates and processes intermediate results. \nUsed in Google, Hadoop, Big Data analytics \n5. WEEK 4 – Cloud Platforms (OpenStack, Azure, GCP) \n5.1 OpenStack \nAn open-source IaaS platform with components:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 5}, page_content='6 \n \n• \nNova (Compute) \n• \nSwift (Object storage) \n• \nCinder (Block storage) \n• \nNeutron (Networking) \n• \nHorizon (Dashboard) \n5.2 Microsoft Azure \nProvides: \n• \nPaaS + SaaS \n• \nMachine Learning Studio \n• \nCosmosDB \n• \nAzure Functions \n5.3 Google Cloud Platform (GCP) \nPopular services: \n• \nCompute Engine \n• \nApp Engine \n• \nBigQuery \n• \nKubernetes Engine \n5.4 Comparative Insights \nParameter \nAzure \nGCP \nOpenStack \nType \nCommercial \nCommercial \nOpen-source \nScalability \nExcellent \nExcellent \nDepends on \ndeployment \nAI Tools \nStrong \nVery strong \nLimited \n \n6. WEEK 5 – SLA Calculation, Resource Management & MapReduce \nTutorial \n6.1 SLA Practical Calculations \nStudents calculate: \n• \nAvailability (%)'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 6}, page_content='7 \n \n• \nDowntime tolerance \n• \nCost estimates \nExample: \nAvailability = MTBF / (MTBF + MTTR) \n6.2 MapReduce Tutorial \nCovered: \n• \nJob submission \n• \nFault tolerance \n• \nDistributed file system integration \n6.3 Resource Management \nEfficient allocation of: \n• \nCPU \n• \nMemory \n• \nStorage \n• \nNetwork bandwidth \nDynamic resource management ensures optimal workload distribution. \n \n7. WEEK 6 – Cloud Security \n7.1 Major Security Concerns \n• \nData breaches \n• \nIdentity theft \n• \nInsecure APIs \n• \nLack of visibility in multi-tenant environments \n7.2 CIA Triad \n1. Confidentiality – Prevent unauthorized data access \n2. Integrity – Prevent unauthorized changes \n3. Availability – Ensure services remain accessible'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 7}, page_content='8 \n \n7.3 SaaS Security \n• \nMulti-Tenant Isolation \n• \nAccess control mechanisms \n• \nData encryption at rest & in transit \n7.4 Broker-based Security \nCloud brokers ensure: \n• \nPolicy enforcement \n• \nSecure marketplaces \n• \nAuthentication and auditing \n8. WEEK 7 – Mobile Cloud, Fog Computing, Geo-Spatial Cloud \n8.1 Mobile Cloud Computing \nOffloads mobile computation to the cloud: \n• \nImproves battery efficiency \n• \nEnables heavy computation on small devices \n8.2 Fog Computing \nProcessing near the data source: \n• \nFaster response \n• \nLower latency \n• \nSuitable for IoT applications \n8.3 Geo-Spatial Cloud \nUsed in: \n• \nGIS analytics \n• \nSatellite data processing \nReal-time mapping'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 8}, page_content='9 \n \n8. WEEK 8 – Containers, IoT, Green Cloud \n9.1 Containers (Docker) \nLightweight virtualization without full OS. \nBenefits: \n• \nFaster deployment \n• \nLightweight \n• \nPortable \n9.2 IoT Cloud \nCloud platforms manage: \n• \nSensor data \n• \nDevice connectivity \n• \nStream processing \n9.3 Sensor Cloud \nHighly scalable environments for sensor networks. \n9.4 Green Cloud \nFocus on: \n• \nReduced energy consumption \n• \nOptimized cooling \n• \nCarbon footprint reduction \n \n10. WEEK 9 – Cloud–Fog Integration, Federation & Resource Management \n10.1 Cloud–Fog Synergy \nCombines centralized cloud with distributed fog nodes. \nBenefits: \n• \nReduced latency \n• \nDecentralized analytics'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 9}, page_content='10 \n \n• \nLocal processing capability \n10.2 Resource Management Across Layers \nCloud and fog layers coordinate: \n• \nOffloading \n• \nMigration \n• \nResource partitioning \n10.3 Cloud Federation \nConnecting multiple cloud platforms to share: \n• \nWorkloads \n• \nResources \n• \nNetworks \n \n11.WEEK 10 – Cloud Migration, Container Demos  \n11.1 Phases of Cloud Migration \n1. Assessment – Evaluate existing systems \n2. Planning – Choose target cloud and architecture \n3. Execution – Move workloads \n4. Optimization – Monitor and enhance post-migration performance \n11.2 Containerization & Orchestration \nCovered: \n• \nDocker creation \n• \nImage builds \n• \nContainer networking \n• \nBasic Kubernetes concept'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 10}, page_content='11 \n \n12. WEEK 11 – Serverless Computing & Sustainable Cloud \n12.1 Dew Computing \nIntegration of local devices + cloud services. \n12.2 Serverless Computing \nFaaS (Function-as-a-Service): \n• \nAWS Lambda \n• \nAzure Functions \n• \nGoogle Cloud Functions \nBenefits: \n• \nNo server management \n• \nPay per execution \n• \nAuto-scaling \n12.3 Sustainable Cloud \n• \nRenewable energy data centers \n• \nReduced power consumption \n• \nEnergy-efficient architecture \n \n13. WEEK 12 – Cloud in 5G, CPS & Case Studies \n13.1 Cloud in 5G Networks \nFeatures: \n• \nUltra-low latency \n• \nNetwork slicing \n• \nEdge-enabled architecture \n13.2 CPS – Cyber Physical Systems \nIntegration of: \n• \nSensors'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-27T15:50:12+05:30', 'source': '..\\data\\pdf\\Mooc report.pdf', 'file_path': '..\\data\\pdf\\Mooc report.pdf', 'total_pages': 12, 'format': 'PDF 1.7', 'title': '', 'author': 'python-docx', 'subject': '', 'keywords': '', 'moddate': '2025-11-27T15:50:12+05:30', 'trapped': '', 'modDate': "D:20251127155012+05'30'", 'creationDate': "D:20251127155012+05'30'", 'page': 11}, page_content='12 \n \n• \nEmbedded systems \n• \nCloud computing \n• \nIoT technologies \n13.3 Case Studies \n1. Spatial Cloud Computing \nUsed in: \n• \nClimate modeling \n• \nGeographic mapping \n• \nNavigation systems \n2. Internet of Health Things (IoHT) \nApplications: \n• \nWearable devices \n• \nRemote monitoring \n• \nPatient data analytics \n13.4 Future Trends \n• \nAI-driven Cloud \n• \nQuantum Cloud Computing \n• \nMulti-cloud orchestration \n• \nAutonomous data centers \n14. Conclusion \nThe NPTEL Cloud Computing course provides a comprehensive understanding of the \ncloud ecosystem, covering everything from basic concepts to advanced architectures \nlike Fog, Edge, Serverless, Dew Computing, and Cloud–5G integration. The course \ndevelops practical and theoretical skills in virtualization, web services, SLA \nmanagement, cloud security, resource monitoring, container orchestration, and \nmigration strategies. \n \nThis knowledge prepares students for real-world cloud environments and emerging \nindustry technologies.')]

# %%
type(pdf_document[0])
# Out:
# langchain_core.documents.base.Document
