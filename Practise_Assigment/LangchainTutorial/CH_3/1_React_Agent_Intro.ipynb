# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature=0)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
result = llm_gemini.invoke("What is my name?")
print(result.content)
# Out:
# As an AI, I don't have access to personal information about you, including your name. I don't retain memory of individual users or their personal details.
#
# You're welcome to tell me if you'd like!
