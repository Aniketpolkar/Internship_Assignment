# %% [markdown]
# ### Structured Output

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite-preview-09-2025",temperature=0.7)

prompt_template = ChatPromptTemplate.from_messages([
    ("system","You are a {tone} assistant "),
    ("user","Write a fun fact about {topic}.Return the result in a key-value pair where key is fact and value is the fact.")
])

user_tone = input("Enter a tone? ")
user_input = input("Enter a topic? ")
ready_prompt = prompt_template.invoke({"topic": user_input, "tone": user_tone})
llm_gemini.invoke(ready_prompt.messages).content
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\google\genai\models.py:5227, in Models.generate_content(self, model, contents, config)
#    5226 i += 1
# -> 5227 response = self._generate_content(
#    5228     model=model, contents=contents, config=parsed_config
#    5229 )
#    5231 function_map = _extra_utils.get_function_map(parsed_config)
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\google\genai\models.py:4009, in Models._generate_content(self, model, contents, config)
#    4007 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4009 response = self._api_client.request(
#    4010     'post', path, request_dict, http_options
#    4011 )
#    4013 if config is not None and getattr(
#    4014     config, 'should_return_http_response', None
#    4015 ):
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\google\genai\_api_client.py:1386, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1383 http_request = self._build_request(
#    1384     http_method, path, request_dict, http_options
#    1385 )
# -> 1386 response = self._request(http_request, http_options, stream=False)
#    1387 response_body = (
#    1388     response.response_stream[0] if response.response_stream else ''
#    1389 )
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\google\genai\_api_client.py:1220, in BaseApiClient._request(self, http_request, http_options, stream)
#    1219     retry = tenacity.Retrying(**retry_kwargs)
# -> 1220     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1222 return self._retry(self._request_once, http_request, stream)
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File C:\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File C:\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\google\genai\_api_client.py:1199, in BaseApiClient._request_once(self, http_request, stream)
#    1192 response = self._httpx_client.request(
#    1193     method=http_request.method,
#    1194     url=http_request.url,
#    (...)   1197     timeout=http_request.timeout,
#    1198 )
# -> 1199 errors.APIError.raise_for_response(response)
#    1200 return HttpResponse(
#    1201     response.headers, response if stream else [response.text]
#    1202 )
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\google\genai\errors.py:121, in APIError.raise_for_response(cls, response)
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\google\genai\errors.py:146, in APIError.raise_error(cls, status_code, response_json, response)
#     145 if 400 <= status_code < 500:
# --> 146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 4.367449268s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[14], line 14
#      12 user_input = input("Enter a topic? ")
#      13 ready_prompt = prompt_template.invoke({"topic": user_input, "tone": user_tone})
# ---> 14 llm_gemini.invoke(ready_prompt.messages).content
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1121, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1112 @override
#    1113 def generate_prompt(
#    1114     self,
#    (...)   1118     **kwargs: Any,
#    1119 ) -> LLMResult:
#    1120     prompt_messages = [p.to_messages() for p in prompts]
# -> 1121     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:931, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     928 for i, m in enumerate(input_messages):
#     929     try:
#     930         results.append(
# --> 931             self._generate_with_cache(
#     932                 m,
#     933                 stop=stop,
#     934                 run_manager=run_managers[i] if run_managers else None,
#     935                 **kwargs,
#     936             )
#     937         )
#     938     except BaseException as e:
#     939         if run_managers:
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1233, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1231     result = generate_from_stream(iter(chunks))
#    1232 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1233     result = self._generate(
#    1234         messages, stop=stop, run_manager=run_manager, **kwargs
#    1235     )
#    1236 else:
#    1237     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3051, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
# -> 3051     _handle_client_error(e, request)
#    3053 return _response_to_result(response)
#
# File d:\Internship\LangchainTutorial\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-lite-preview-09-2025' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 4.367449268s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}

# %% [markdown]
# # **Using pydentic model**

# %%
from pydantic import Field
from pydantic import BaseModel
# data validation using pydantic
class llm_Schema(BaseModel):
    setup:str = Field(description="setup of the joke")
    punchline:str = Field(description="punchline of the joke")
    meaning:str = Field(description="meaning of the joke")
    
# data parsing 
obj = llm_Schema(**{"setup":"some setup","punchline":"some punchline","meaning":"some meaning"})
obj
# Out:
# llm_Schema(setup='some setup', punchline='some punchline', meaning='some meaning')

# %%
llm_structured_output = llm_gemini.with_structured_output(llm_Schema)
result = llm_structured_output.invoke("Tell me a joke")

# %%
print(result)
# Out:
# setup="Why don't scientists trust atoms?" punchline='Because they make up everything!' meaning="This is a pun. Atoms are the fundamental building blocks of matter, so they literally 'make up everything.' The joke plays on the double meaning of 'make up' as both 'compose' and 'fabricate/lie.'"

# %% [markdown]
# # **Using TypedDict**

# %%
from typing import TypedDict

class llm_schema_td(TypedDict):
    setup:str
    punchline:str
    meaning:str
    
obj = llm_schema_td({"ketchup":"some setup","punchline":"some punchline","meaning":"some meaning"})
print(obj)
# Out:
# {'ketchup': 'some setup', 'punchline': 'some punchline', 'meaning': 'some meaning'}

# %%
llm_structured_typed_output = llm_gemini.with_structured_output(llm_schema_td)

result = llm_structured_typed_output.invoke("Tell me a joke")
print(result)
# Out:
# {'setup': "Why don't scientists trust atoms?", 'punchline': 'Because they make up everything!', 'meaning': "This is a pun based on the dual meaning of 'make up': to constitute or form something, and to fabricate or lie. Atoms are the fundamental building blocks of matter, so they 'make up everything' physically, but the joke implies they are untrustworthy liars."}
