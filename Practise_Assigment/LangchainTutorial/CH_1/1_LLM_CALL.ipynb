# %% [markdown]
# ## LLM CALL

# %%
print("Hello world")

# %%
from google import genai
import os

client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = client.models.generate_content(
    model="gemini-2.5-flash-lite-preview-09-2025",
    contents="Tell me a fun fact about pune give in 2 sentences"
)
print(response.text)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite-preview-09-2025",
    temperature=0.3,
)
response = llm.invoke("tell me a single slogan on shivaji maharaj?")
print(response.text)

# %%
from langchain.chat_models import init_chat_model

llm_gemini = init_chat_model(
    model="gemini-2.5-flash-preview-09-2025",
    model_provider="google_genai"
)

response = llm_gemini.invoke("Which are the best 10 forts in maharashtra give me list only?")
print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Here are 10 of the most highly regarded and historically significant forts in Maharashtra:
#
# 1. **Raigad Fort**
# 2. **Shivneri Fort**
# 3. **Sindhudurg Fort**
# 4. **Pratapgad Fort**
# 5. **Torna Fort (Prachandgad)**
# 6. **Lohagad Fort**
# 7. **Murud-Janjira Fort**
# 8. **Panhala Fort**
# 9. **Purandar Fort**
# 10. **Harishchandragad Fort**
