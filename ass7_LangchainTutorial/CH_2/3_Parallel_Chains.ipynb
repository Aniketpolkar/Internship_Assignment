# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite-preview-09-2025",temperature=0)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %% [markdown]
# # **CHAIN With Parallel Chains**

# %%
# Task-1 [prompt] 
prompt_template = ChatPromptTemplate.from_messages(
    ["system","You are movie summerizer.",
    ("human","Please summarize the movie in short:{input}")
    ])

# Task-2 [LLM]
llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite-preview-09-2025",temperature=0)

# Task 3 [String Parser]
str_parser = StrOutputParser()
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
# Task 4 [Custom runnable]
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str)->dict:
    return {"text":text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %% [markdown]
# # **Parallel Chain 1**

# %%
from langchain_core.output_parsers import StrOutputParser
# Task 1 [Prompt]
linkdin_prompt = ChatPromptTemplate.from_messages([
    ("system","You are a linkdin post generator "),
    ("human","create a post for the following text for linkdin : {text}")
])

# Task 2 [LLM]
llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite-preview-09-2025",temperature=0)

# Task 3 [Str Parser]
str_parser = StrOutputParser()

chain_linkdin = linkdin_prompt | llm_gemini | str_parser
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %% [markdown]
# # **Parallel Chain 2**

# %%
from langchain_core.runnables import RunnableParallel,RunnableLambda

# %%
def insta_chain(text:dict):
    text = text["text"]

    # Task 1 [Prompt]
    insta_prompt = ChatPromptTemplate.from_messages([
        ("system","You are a insta post generator "),
        ("human","create a post for the following text for insta : {text}")
    ])

    # Task 2 [LLM]
    llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite-preview-09-2025",temperature=0)

    # Task 3 [Str Parser]
    str_parser = StrOutputParser()

    chain_insta = insta_prompt | llm_gemini | str_parser

    result = chain_insta.invoke(text)
    return result   


insta_chain_runnable = RunnableLambda(insta_chain)

# %% [markdown]
# # **Final Orchestration**

# %%
final_chain = (
    prompt_template | llm_gemini | str_parser | dictionary_maker 
    | RunnableParallel(branches ={"linkedin":chain_linkdin,"instagram":insta_chain_runnable})
)

# %%
final_chain.invoke("Chhava")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# {'branches': {'linkedin': 'Here are a few options for your LinkedIn post, ranging in tone and focus. Choose the one that best suits your audience!\n\n---\n\n## Option 1: Focus on History & Leadership (Professional Tone)\n\n**💡 Post:**\n\nExcited to see the upcoming film **"Chhava,"** which promises a deep dive into the life and legacy of **Chhatrapati Sambhaji Maharaj.**\n\nAs the son and successor to Chhatrapati Shivaji Maharaj, Sambhaji Maharaj\'s reign was defined by incredible **valor, strategic brilliance, and unwavering commitment** in the face of overwhelming odds.\n\nThis film isn\'t just entertainment; it’s a powerful reminder of leadership under extreme pressure and the ultimate sacrifice made in the fight against oppression. A must-watch for anyone interested in Indian history and resilient leadership.\n\n#Chhava #SambhajiMaharaj #IndianHistory #Leadership #Inspiration #HistoricalFilm\n\n---\n\n## Option 2: Focus on Valor & Sacrifice (More Engaging/Action-Oriented)\n\n**⚔️ Post:**\n\nGet ready for a cinematic portrayal of true grit!\n\nThe film **"Chhava"** brings the epic story of **Chhatrapati Sambhaji Maharaj** to the big screen. This isn\'t just a historical drama; it’s a testament to unmatched courage.\n\nThe narrative highlights the **valor, strategic brilliance, and ultimate sacrifice** of Sambhaji Maharaj as he stood firm against the Mughal Empire. A powerful story of resilience that continues to inspire generations.\n\nWhat historical figure\'s story do you think deserves a major cinematic spotlight next? Share your thoughts below! 👇\n\n#ChhavaMovie #ChhatrapatiSambhajiMaharaj #Valor #Strategy #IndianCinema #History\n\n---\n\n## Option 3: Short & Direct Announcement\n\n**🎬 Post:**\n\nMark your calendars for **"Chhava"!**\n\nThis historical action film chronicles the extraordinary life of **Chhatrapati Sambhaji Maharaj**, son and successor to Shivaji Maharaj.\n\nThe core message? A powerful depiction of **valor, strategic brilliance, and the ultimate sacrifice** made in the relentless fight against the Mughal Empire. Looking forward to this powerful tribute!\n\n#Chhava #SambhajiMaharaj #HistoricalAction #MustWatch #Legacy\n\n---\n\n### **Pro-Tip for Posting:**\n\n*   **Add an Image/Poster:** LinkedIn posts with relevant visuals get significantly higher engagement. If you have the official poster for "Chhava," use it!\n*   **Tag Relevant People/Pages:** If you know the director, producer, or official movie page, tag them to increase reach.',
#   'instagram': 'Here are a few options for your Instagram post, ranging in style. Choose the one that best fits your overall aesthetic!\n\n---\n\n## Option 1: Bold & Action-Oriented (Great for a movie poster/trailer clip)\n\n📸 **Image/Video Suggestion:** A powerful still of Sambhaji Maharaj or an intense action scene.\n\n**Caption:**\n\n🔥 **The Lion\'s Legacy Continues!** 🔥\n\nGet ready to witness the untold saga of valor, strategy, and ultimate sacrifice. **"CHHAVA"** brings to life the incredible journey of **Chhatrapati Sambhaji Maharaj**—the son and rightful successor of Chhatrapati Shivaji Maharaj.\n\nThis isn\'t just history; it\'s a testament to unwavering courage against tyranny. See the strategic brilliance and the fierce fight against the oppressive Mughal Empire unfold on the big screen.\n\n**Valor. Brilliance. Sacrifice.**\n\nAre you ready for the epic? 👇\n\n#Chhava #SambhajiMaharaj #Chhatrapati #HistoricalEpic #ActionFilm #MarathiCinema #IndianHistory #Valor #NewMovie\n\n---\n\n## Option 2: Informative & Respectful (Good for a character introduction or announcement)\n\n📸 **Image/Video Suggestion:** A more formal portrait or title card.\n\n**Caption:**\n\nHonoring a true warrior. 👑\n\nWe are thrilled to announce **"CHHAVA,"** a historical action film dedicated to the life of **Chhatrapati Sambhaji Maharaj**.\n\nAs the successor to the great Shivaji Maharaj, Sambhaji Maharaj’s reign was defined by relentless courage. This film dives deep into his **valor, strategic brilliance, and the ultimate sacrifice** he made while fiercely resisting the Mughal Empire.\n\nA story that demands to be told. Stay tuned for more updates!\n\n#ChhavaMovie #SambhajiRaje #HistoryReimagined #IndianCinema #WarriorKing #Respect #MustWatch\n\n---\n\n## Option 3: Short & Punchy (Ideal for a quick teaser or story swipe-up)\n\n📸 **Image/Video Suggestion:** A close-up shot emphasizing intensity.\n\n**Caption:**\n\nHe fought for every inch. He sacrificed everything.\n\n**CHHAVA** is the story of **Chhatrapati Sambhaji Maharaj**—his unmatched valor and strategic genius in the face of overwhelming odds.\n\nWitness the fight against the Mughal Empire. ⚔️\n\n#Chhava #SambhajiMaharaj #Epic #ComingSoon #History\n\n---\n\n### **Remember to add these essential elements to your final post:**\n\n*   **Tag the official movie/production accounts.**\n*   **Use relevant emojis** to break up the text (like 👑, 🔥, ⚔️, 🦁).\n*   **Include a strong Call to Action** (e.g., "Tag a history lover!" or "What are you most excited to see?").'}}

# %% [markdown]
# # *Chain as runnable*

# %%
# task 1 Butify Function

def butify(final_response :dict)->dict:
    linkedin_response = final_response["branches"]["linkedin"]
    instagram_response = final_response["branches"]["instagram"]
    return {"linkedin":linkedin_response,"instagram":instagram_response}

beautify_runnable = RunnableLambda(butify)

# Task 2 Final Chain - Beautified chain
beautified_chain = final_chain | beautify_runnable

beautified_chain.invoke("pushpa")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# {'linkedin': 'Here are a few options for a LinkedIn post based on the text, catering to different angles:\n\n---\n\n## Option 1: Focusing on Leadership & Ambition (More Professional Tone)\n\n**🎬 From Coolie to Kingpin: Lessons in Unstoppable Ambition from \'Pushpa: The Rise\'**\n\nThe story of **Pushpa Raj** in *Pushpa: The Rise* is more than just an action film; it\'s a masterclass in strategic ascent within a complex, high-stakes environment.\n\nWatching Pushpa navigate the brutal hierarchy of the red sandalwood smuggling syndicate in the Seshachalam forests offers fascinating parallels to corporate strategy:\n\n* **Identifying the Gap:** Recognizing an opportunity where others see only risk.\n* **Ruthless Execution:** The importance of decisive action when climbing the ladder.\n* **Building an Empire:** Understanding the ecosystem you operate within, whether it\'s a forest syndicate or a market sector.\n\nIt’s a gritty reminder that true leadership often requires navigating the grey areas and overcoming immense systemic resistance.\n\n**What unconventional paths have you seen lead to massive success?**\n\n#Leadership #Strategy #Ambition #BusinessLessons #PushpaTheRise #IndianCinema\n\n---\n\n## Option 2: Focusing on Grit, Resilience, and Overcoming Obstacles (Motivational Tone)\n\n**🔥 The Grind is Real: What \'Pushpa: The Rise\' Teaches Us About Resilience**\n\nIf you\'re looking for a story about sheer willpower, look no further than **Pushpa Raj** in *Pushpa: The Rise*.\n\nThis film chronicles an incredible journey: starting as a coolie and battling rivals and law enforcement to dominate the red sandalwood trade. It’s a powerful narrative about what happens when ambition meets relentless execution.\n\nIn our professional lives, we all face "syndicates" (competitors, market barriers, internal politics). Pushpa’s success is rooted in his refusal to accept his starting position.\n\n**Are you ready to fight for your position at the top?**\n\n#Resilience #Motivation #CareerGrowth #Grit #SuccessMindset #Pushpa\n\n---\n\n## Option 3: Short, Punchy, and Engaging (Focus on the Narrative Hook)\n\n**From Laborer to Kingpin: The Rise of Pushpa Raj.**\n\nJust finished watching *Pushpa: The Rise*—an intense, action-packed look at how one man, **Pushpa Raj**, clawed his way to the top of the dangerous red sandalwood smuggling world in Andhra Pradesh.\n\nIt’s a gripping study in power dynamics, territorial control, and the cost of becoming the undisputed leader. Highly recommend for anyone interested in high-stakes strategy and narrative tension.\n\n**Have you seen it? What was your biggest takeaway?** 👇\n\n#FilmReview #Action #Strategy #PowerDynamics #MustWatch #PushpaTheRise\n\n---\n\n**Remember to choose the option that best aligns with your personal brand on LinkedIn!**',
#  'instagram': 'Here are a few options for your Instagram post, playing with different vibes:\n\n---\n\n## Option 1: Action-Focused & Punchy (Great for a Reel/Trailer Clip)\n\n📸 **Image/Video Suggestion:** A powerful still of Allu Arjun as Pushpa, or a dynamic action scene.\n\n**Caption:**\n\n🔥 **Pushpa: The Rise.** 🔥\n\nFrom a humble coolie to the undisputed kingpin. Witness the raw, gritty journey of **Pushpa Raj** as he carves his empire out of the dangerous Seshachalam forests. 🌲💰\n\nThis isn\'t just a story; it\'s a revolution. Red Sandalwood smuggling, relentless battles, and a rise that shook the system.\n\nAre you ready for the reign? 👑\n\n#PushpaTheRise #PushpaRaj #AlluArjun #Tollywood #ActionMovie #RedSandalwood #Kingpin #MustWatch #IndianCinema\n\n---\n\n## Option 2: Character & Intrigue Focused (Good for a Poster or Character Shot)\n\n📸 **Image/Video Suggestion:** A close-up, intense shot of Pushpa Raj.\n\n**Caption:**\n\nHe started at the bottom. Now, he owns the jungle. 🤫\n\nMeet **Pushpa Raj**—the man who defied gravity and climbed the ranks of the ruthless red sandalwood smuggling syndicate. Every step up meant a new enemy, every victory, a bigger target on his back.\n\nThis is the story of ambition, power, and survival in the heart of Andhra Pradesh. 💥\n\n**Pushpa: The Rise.** See the legend unfold.\n\n➡️ Tag a friend who needs to watch this epic!\n\n#Pushpa #AlluArjunFan #GrittyCinema #RiseToPower #SandalwoodSmuggling #Blockbuster #MovieRecommendation #PushpaFever\n\n---\n\n## Option 3: Short & Direct (Ideal for a Story Swipe-Up or Quick Post)\n\n📸 **Image/Video Suggestion:** The official movie poster.\n\n**Caption:**\n\n**PUSHPA: THE RISE.** 🚨\n\nCoolie. Smuggler. Kingpin.\n\nFollow **Pushpa Raj** as he battles rivals and the law to dominate the red sandalwood trade in the Seshachalam forests. Pure, unadulterated action. 🪵⚔️\n\nTap the link in bio to stream now!\n\n#PushpaTheRise #AlluArjun #ActionPacked #NewMovie #MustWatch #KingOfSandalwood\n\n---\n\n### 💡 Pro-Tip for Instagram:\n\n*   **Use Emojis:** They break up the text and add visual interest.\n*   **Tag Relevant Accounts:** Tag the official movie account, the lead actor, and the production house.\n*   **Call to Action:** Encourage comments or shares (e.g., "What\'s your favorite Pushpa dialogue?").'}
